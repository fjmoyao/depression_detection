# %%
import pandas as pd
from pathlib import Path
import os
import warnings
warnings.filterwarnings(action="ignore", category=UserWarning)
import optuna
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
import joblib

# %%
#Se leen los datos y se seleccionan las variables que presentan una diferencia
# entre los individuos que presentan estres y los que no
data_path = Path(os.getcwd()).parent / "data" / "gold"

# %%
#Loads different feature sets
df_manual = pd.read_csv(os.path.join(data_path,'manual_features_train.csv'))
X_manual = df_manual.iloc[:,:-1]
y_manual = df_manual.iloc[:,-1]

df_tfidf = pd.read_csv(os.path.join(data_path,'tfidf_features_train.csv'))
X_tfidf = df_tfidf.iloc[:,:-1]
y_tfidf = df_tfidf.iloc[:,-1]

df_mpnet = pd.read_csv(os.path.join(data_path,'mpnet_features_train.csv'))
X_mpnet = df_mpnet.iloc[:,:-1]
y_mpnet = df_mpnet.iloc[:,-1]

df_distilroberta = pd.read_csv(os.path.join(data_path,'distilroberta_features_train.csv'))
X_distilroberta = df_distilroberta.iloc[:,:-1]
y_distilroberta = df_distilroberta.iloc[:,-1]

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ##### Manual

# %%
def objective_manual_rf(trial):
    
    num_trees = trial.suggest_int("rf_n_estimators", 10, 1000)
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int("rf_max_depth", 2, 1000)
    classifier_obj = RandomForestClassifier(n_estimators=num_trees, criterion=criterion, max_depth=max_depth)

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(classifier_obj, X_manual, y_manual, n_jobs=-1, cv=3, scoring="f1")
    fscore = score.mean()
    return fscore

study = optuna.create_study(direction="maximize",study_name="manual_rf",
                             sampler=optuna.samplers.NSGAIISampler())

# Adding Attributes to Study
study.set_user_attr('contributors', ['Francisco'])
study.set_user_attr('dataset', 'Manual')

# Store and load using joblib:
study_path = os.path.join(data_path,'manual_rf.pkl')
if not os.path.isfile(study_path):
    joblib.dump(study, study_path)

study = joblib.load(study_path)

study.optimize(objective_manual_rf, n_trials=100)
joblib.dump(study, study_path)
# Out:
# [I 2024-06-26 05:14:29,077] A new study created in memory with name: manual_rf
# [I 2024-06-26 05:14:29,889] Trial 100 finished with value: 0.5973599965430418 and parameters: {'rf_n_estimators': 282, 'rf_criterion': 'gini', 'rf_max_depth': 704}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:14:47,889] Trial 101 finished with value: 0.6041289476462776 and parameters: {'rf_n_estimators': 5887, 'rf_criterion': 'gini', 'rf_max_depth': 8320}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:15:11,632] Trial 102 finished with value: 0.6042503735445656 and parameters: {'rf_n_estimators': 6487, 'rf_criterion': 'entropy', 'rf_max_depth': 2418}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:15:41,840] Trial 103 finished with value: 0.6033670771393015 and parameters: {'rf_n_estimators': 9879, 'rf_criterion': 'gini', 'rf_max_depth': 6144}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:16:01,932] Trial 104 finished with value: 0.6026197930035523 and parameters: {'rf_n_estimators': 7043, 'rf_criterion': 'gini', 'rf_max_depth': 4840}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:16:08,200] Trial 105 finished with value: 0.6028051357394318 and parameters: {'rf_n_estimators': 2277, 'rf_criterion': 'gini', 'rf_max_depth': 4485}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:16:16,075] Trial 106 finished with value: 0.6052291464412128 and parameters: {'rf_n_estimators': 2901, 'rf_criterion': 'gini', 'rf_max_depth': 3733}. Best is trial 1 with value: 0.6902527492618468.
# [I 2024-06-26 05:16:37,892] Trial 107 finished with value: 0.6059332234336393 and parameters: {'rf_n_estimators': 6094, 'rf_criterion': 'entropy', 'rf_max_depth': 811}. Best is trial 1 with value: 0.6902527492618468.
# [W 2024-06-26 05:16:38,302] Trial 108 failed with parameters: {'rf_n_estimators': 4820, 'rf_criterion': 'entropy', 'rf_max_depth': 4548} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\franc.FJMOYAO\AppData\Local\Temp\ipykernel_7096\3143003194.py", line 9, in objective_manual_rf
#     score = model_selection.cross_val_score(classifier_obj, X_manual, y_manual, n_jobs=-1, cv=3, scoring="f1")
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\model_selection\_validation.py", line 712, in cross_val_score
#     cv_results = cross_validate(
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\model_selection\_validation.py", line 423, in cross_validate
#     results = parallel(
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\parallel.py", line 67, in __call__
#     return super().__call__(iterable_with_config)
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
# KeyboardInterrupt
# [W 2024-06-26 05:16:38,304] Trial 108 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 27
#      23     joblib.dump(study, study_path)
#      25 study = joblib.load(study_path)
# ---> 27 study.optimize(objective_manual_rf, n_trials=100)
#      28 joblib.dump(study, study_path)
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[11], line 9, in objective_manual_rf(trial)
#       6 classifier_obj = RandomForestClassifier(n_estimators=num_trees, criterion=criterion, max_depth=max_depth)
#       8 # Step 3: Scoring method:
# ----> 9 score = model_selection.cross_val_score(classifier_obj, X_manual, y_manual, n_jobs=-1, cv=3, scoring="f1")
#      10 fscore = score.mean()
#      11 return fscore
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\model_selection\_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\model_selection\_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\sklearn\utils\parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\franc.FJMOYAO\miniconda3\envs\tesis\lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# ##### TFIDF

# %%
def objective_tfidf_rf(trial):
    
    num_trees = trial.suggest_int("rf_n_estimators", 10, 1000)
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int("rf_max_depth", 2, 1000)
    classifier_obj = RandomForestClassifier(n_estimators=num_trees, criterion=criterion, max_depth=max_depth)

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(classifier_obj, X_tfidf, y_tfidf, n_jobs=-1, cv=3, scoring="f1")
    fscore = score.mean()
    return fscore

study = optuna.create_study(direction="maximize",study_name="tfidf_rf",
                             sampler=optuna.samplers.NSGAIISampler())

# Adding Attributes to Study
study.set_user_attr('contributors', ['Francisco'])
study.set_user_attr('dataset', 'tfidf')

# Store and load using joblib:
study_path = os.path.join(data_path,'tfidf_rf.pkl')
if not os.path.isfile(study_path):
    joblib.dump(study, study_path)

study = joblib.load(study_path)

study.optimize(objective_tfidf_rf, n_trials=100)
joblib.dump(study, study_path)
# Out:
# [I 2024-06-26 05:17:20,569] A new study created in memory with name: tfidf_rf
# [I 2024-06-26 05:17:25,227] Trial 0 finished with value: 0.7409969664443287 and parameters: {'rf_n_estimators': 430, 'rf_criterion': 'gini', 'rf_max_depth': 19}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:17:27,359] Trial 1 finished with value: 0.7285736115686757 and parameters: {'rf_n_estimators': 54, 'rf_criterion': 'entropy', 'rf_max_depth': 719}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:17:44,599] Trial 2 finished with value: 0.7401123905880231 and parameters: {'rf_n_estimators': 856, 'rf_criterion': 'gini', 'rf_max_depth': 632}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:18:02,200] Trial 3 finished with value: 0.737647614804691 and parameters: {'rf_n_estimators': 817, 'rf_criterion': 'entropy', 'rf_max_depth': 495}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:18:06,779] Trial 4 finished with value: 0.734441272069226 and parameters: {'rf_n_estimators': 228, 'rf_criterion': 'gini', 'rf_max_depth': 460}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:18:29,246] Trial 5 finished with value: 0.7369599417923042 and parameters: {'rf_n_estimators': 938, 'rf_criterion': 'entropy', 'rf_max_depth': 927}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:18:48,775] Trial 6 finished with value: 0.73830606074018 and parameters: {'rf_n_estimators': 624, 'rf_criterion': 'entropy', 'rf_max_depth': 636}. Best is trial 0 with value: 0.7409969664443287.
# [I 2024-06-26 05:19:16,457] Trial 7 finished with value: 0.7411652519029666 and parameters: {'rf_n_estimators': 960, 'rf_criterion': 'gini', 'rf_max_depth': 346}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:19:27,838] Trial 8 finished with value: 0.7371823179574517 and parameters: {'rf_n_estimators': 358, 'rf_criterion': 'entropy', 'rf_max_depth': 945}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:19:32,688] Trial 9 finished with value: 0.7316315126950986 and parameters: {'rf_n_estimators': 147, 'rf_criterion': 'entropy', 'rf_max_depth': 251}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:19:58,275] Trial 10 finished with value: 0.7400081287668526 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'gini', 'rf_max_depth': 582}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:19:59,489] Trial 11 finished with value: 0.7168065741125101 and parameters: {'rf_n_estimators': 27, 'rf_criterion': 'gini', 'rf_max_depth': 310}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:20:27,645] Trial 12 finished with value: 0.7373418475960013 and parameters: {'rf_n_estimators': 975, 'rf_criterion': 'gini', 'rf_max_depth': 796}. Best is trial 7 with value: 0.7411652519029666.
# [I 2024-06-26 05:20:39,138] Trial 13 finished with value: 0.7440408458800717 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'entropy', 'rf_max_depth': 324}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:21:01,092] Trial 14 finished with value: 0.7377179974596103 and parameters: {'rf_n_estimators': 754, 'rf_criterion': 'gini', 'rf_max_depth': 332}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:21:20,400] Trial 15 finished with value: 0.7367576490725504 and parameters: {'rf_n_estimators': 624, 'rf_criterion': 'entropy', 'rf_max_depth': 496}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:21:25,177] Trial 16 finished with value: 0.7354912510676376 and parameters: {'rf_n_estimators': 154, 'rf_criterion': 'gini', 'rf_max_depth': 638}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:21:46,119] Trial 17 finished with value: 0.7401143282027723 and parameters: {'rf_n_estimators': 940, 'rf_criterion': 'entropy', 'rf_max_depth': 269}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:21:51,220] Trial 18 finished with value: 0.7422261738906287 and parameters: {'rf_n_estimators': 263, 'rf_criterion': 'gini', 'rf_max_depth': 727}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:03,526] Trial 19 finished with value: 0.741552100379784 and parameters: {'rf_n_estimators': 639, 'rf_criterion': 'gini', 'rf_max_depth': 709}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:15,954] Trial 20 finished with value: 0.7368210990668688 and parameters: {'rf_n_estimators': 610, 'rf_criterion': 'entropy', 'rf_max_depth': 414}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:23,524] Trial 21 finished with value: 0.7388027853420832 and parameters: {'rf_n_estimators': 386, 'rf_criterion': 'gini', 'rf_max_depth': 642}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:32,330] Trial 22 finished with value: 0.7386899912333683 and parameters: {'rf_n_estimators': 445, 'rf_criterion': 'gini', 'rf_max_depth': 132}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:45,157] Trial 23 finished with value: 0.7401401004493788 and parameters: {'rf_n_estimators': 618, 'rf_criterion': 'entropy', 'rf_max_depth': 877}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:46,944] Trial 24 finished with value: 0.7286748507430866 and parameters: {'rf_n_estimators': 73, 'rf_criterion': 'gini', 'rf_max_depth': 419}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:48,570] Trial 25 finished with value: 0.724787996940162 and parameters: {'rf_n_estimators': 70, 'rf_criterion': 'gini', 'rf_max_depth': 892}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:22:52,999] Trial 26 finished with value: 0.7348885907326298 and parameters: {'rf_n_estimators': 204, 'rf_criterion': 'entropy', 'rf_max_depth': 238}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:11,669] Trial 27 finished with value: 0.7435484419796836 and parameters: {'rf_n_estimators': 979, 'rf_criterion': 'gini', 'rf_max_depth': 809}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:22,677] Trial 28 finished with value: 0.7403122487429648 and parameters: {'rf_n_estimators': 566, 'rf_criterion': 'gini', 'rf_max_depth': 392}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:25,418] Trial 29 finished with value: 0.7390154875345035 and parameters: {'rf_n_estimators': 125, 'rf_criterion': 'entropy', 'rf_max_depth': 886}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:36,567] Trial 30 finished with value: 0.739787670790156 and parameters: {'rf_n_estimators': 571, 'rf_criterion': 'gini', 'rf_max_depth': 924}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:37,277] Trial 31 finished with value: 0.7069652518991436 and parameters: {'rf_n_estimators': 24, 'rf_criterion': 'gini', 'rf_max_depth': 665}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:23:56,395] Trial 32 finished with value: 0.7394732194927415 and parameters: {'rf_n_estimators': 976, 'rf_criterion': 'gini', 'rf_max_depth': 512}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:00,024] Trial 33 finished with value: 0.7406304209310876 and parameters: {'rf_n_estimators': 177, 'rf_criterion': 'gini', 'rf_max_depth': 477}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:01,810] Trial 34 finished with value: 0.7284783585763951 and parameters: {'rf_n_estimators': 90, 'rf_criterion': 'entropy', 'rf_max_depth': 66}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:04,710] Trial 35 finished with value: 0.7365004774921619 and parameters: {'rf_n_estimators': 131, 'rf_criterion': 'entropy', 'rf_max_depth': 411}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:22,542] Trial 36 finished with value: 0.7389509335902713 and parameters: {'rf_n_estimators': 873, 'rf_criterion': 'entropy', 'rf_max_depth': 599}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:40,891] Trial 37 finished with value: 0.7390856574450488 and parameters: {'rf_n_estimators': 977, 'rf_criterion': 'entropy', 'rf_max_depth': 87}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:24:53,358] Trial 38 finished with value: 0.7381045701334451 and parameters: {'rf_n_estimators': 590, 'rf_criterion': 'entropy', 'rf_max_depth': 789}. Best is trial 13 with value: 0.7440408458800717.
# [I 2024-06-26 05:25:00,190] Trial 39 finished with value: 0.7461060309446225 and parameters: {'rf_n_estimators': 350, 'rf_criterion': 'gini', 'rf_max_depth': 746}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:15,001] Trial 40 finished with value: 0.7385180250560763 and parameters: {'rf_n_estimators': 732, 'rf_criterion': 'entropy', 'rf_max_depth': 328}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:27,704] Trial 41 finished with value: 0.7413743639564089 and parameters: {'rf_n_estimators': 623, 'rf_criterion': 'entropy', 'rf_max_depth': 265}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:34,641] Trial 42 finished with value: 0.7266557265508308 and parameters: {'rf_n_estimators': 335, 'rf_criterion': 'entropy', 'rf_max_depth': 955}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:38,199] Trial 43 finished with value: 0.736735444996888 and parameters: {'rf_n_estimators': 177, 'rf_criterion': 'gini', 'rf_max_depth': 770}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:46,704] Trial 44 finished with value: 0.7424787060771965 and parameters: {'rf_n_estimators': 443, 'rf_criterion': 'gini', 'rf_max_depth': 579}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:47,686] Trial 45 finished with value: 0.721639824717138 and parameters: {'rf_n_estimators': 38, 'rf_criterion': 'gini', 'rf_max_depth': 754}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:25:54,809] Trial 46 finished with value: 0.7402892967742355 and parameters: {'rf_n_estimators': 364, 'rf_criterion': 'gini', 'rf_max_depth': 256}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:05,110] Trial 47 finished with value: 0.7381418191568284 and parameters: {'rf_n_estimators': 501, 'rf_criterion': 'entropy', 'rf_max_depth': 771}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:05,964] Trial 48 finished with value: 0.7120016939316424 and parameters: {'rf_n_estimators': 30, 'rf_criterion': 'entropy', 'rf_max_depth': 466}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:07,685] Trial 49 finished with value: 0.7294069316567849 and parameters: {'rf_n_estimators': 78, 'rf_criterion': 'gini', 'rf_max_depth': 720}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:20,557] Trial 50 finished with value: 0.7391844788166141 and parameters: {'rf_n_estimators': 664, 'rf_criterion': 'gini', 'rf_max_depth': 709}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:38,621] Trial 51 finished with value: 0.7392693921543368 and parameters: {'rf_n_estimators': 940, 'rf_criterion': 'gini', 'rf_max_depth': 269}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:44,607] Trial 52 finished with value: 0.7357285955522413 and parameters: {'rf_n_estimators': 292, 'rf_criterion': 'gini', 'rf_max_depth': 597}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:55,676] Trial 53 finished with value: 0.7359818395058536 and parameters: {'rf_n_estimators': 571, 'rf_criterion': 'gini', 'rf_max_depth': 924}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:26:57,077] Trial 54 finished with value: 0.7250736761903296 and parameters: {'rf_n_estimators': 54, 'rf_criterion': 'gini', 'rf_max_depth': 719}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:27:15,612] Trial 55 finished with value: 0.7429512626565198 and parameters: {'rf_n_estimators': 975, 'rf_criterion': 'gini', 'rf_max_depth': 512}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:27:30,416] Trial 56 finished with value: 0.7406868928481037 and parameters: {'rf_n_estimators': 770, 'rf_criterion': 'gini', 'rf_max_depth': 746}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:27:43,505] Trial 57 finished with value: 0.7406329713724028 and parameters: {'rf_n_estimators': 691, 'rf_criterion': 'gini', 'rf_max_depth': 872}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:27:50,881] Trial 58 finished with value: 0.7417603035366193 and parameters: {'rf_n_estimators': 975, 'rf_criterion': 'gini', 'rf_max_depth': 19}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:28:04,702] Trial 59 finished with value: 0.7352670534743236 and parameters: {'rf_n_estimators': 719, 'rf_criterion': 'gini', 'rf_max_depth': 579}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:28:20,237] Trial 60 finished with value: 0.7402298324336088 and parameters: {'rf_n_estimators': 808, 'rf_criterion': 'gini', 'rf_max_depth': 709}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:28:39,742] Trial 61 finished with value: 0.7378088084445485 and parameters: {'rf_n_estimators': 960, 'rf_criterion': 'gini', 'rf_max_depth': 346}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:28:49,230] Trial 62 finished with value: 0.7392079436799622 and parameters: {'rf_n_estimators': 445, 'rf_criterion': 'entropy', 'rf_max_depth': 132}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:28:52,855] Trial 63 finished with value: 0.7329655759286556 and parameters: {'rf_n_estimators': 177, 'rf_criterion': 'gini', 'rf_max_depth': 924}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:29:10,591] Trial 64 finished with value: 0.7411744369697358 and parameters: {'rf_n_estimators': 938, 'rf_criterion': 'gini', 'rf_max_depth': 727}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:29:29,048] Trial 65 finished with value: 0.7380036749845508 and parameters: {'rf_n_estimators': 971, 'rf_criterion': 'gini', 'rf_max_depth': 789}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:29:41,941] Trial 66 finished with value: 0.7354298018009279 and parameters: {'rf_n_estimators': 624, 'rf_criterion': 'entropy', 'rf_max_depth': 636}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:29:57,497] Trial 67 finished with value: 0.7368938636576431 and parameters: {'rf_n_estimators': 762, 'rf_criterion': 'entropy', 'rf_max_depth': 495}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:30:14,472] Trial 68 finished with value: 0.7443685260095433 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'gini', 'rf_max_depth': 582}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:30:28,516] Trial 69 finished with value: 0.7387760662987479 and parameters: {'rf_n_estimators': 730, 'rf_criterion': 'gini', 'rf_max_depth': 477}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:30:36,132] Trial 70 finished with value: 0.740206171919234 and parameters: {'rf_n_estimators': 386, 'rf_criterion': 'gini', 'rf_max_depth': 456}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:30:47,145] Trial 71 finished with value: 0.7381879270342108 and parameters: {'rf_n_estimators': 566, 'rf_criterion': 'gini', 'rf_max_depth': 582}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:31:03,371] Trial 72 finished with value: 0.740161587957686 and parameters: {'rf_n_estimators': 846, 'rf_criterion': 'gini', 'rf_max_depth': 891}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:31:11,773] Trial 73 finished with value: 0.735240336860325 and parameters: {'rf_n_estimators': 443, 'rf_criterion': 'entropy', 'rf_max_depth': 87}. Best is trial 39 with value: 0.7461060309446225.
# [I 2024-06-26 05:31:18,886] Trial 74 finished with value: 0.7477008418169214 and parameters: {'rf_n_estimators': 364, 'rf_criterion': 'gini', 'rf_max_depth': 256}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:31:37,533] Trial 75 finished with value: 0.7374480325547723 and parameters: {'rf_n_estimators': 975, 'rf_criterion': 'gini', 'rf_max_depth': 796}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:31:39,285] Trial 76 finished with value: 0.7255378591990894 and parameters: {'rf_n_estimators': 78, 'rf_criterion': 'gini', 'rf_max_depth': 148}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:31:46,319] Trial 77 finished with value: 0.7381201238452372 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'gini', 'rf_max_depth': 324}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:04,956] Trial 78 finished with value: 0.7393868306128796 and parameters: {'rf_n_estimators': 960, 'rf_criterion': 'gini', 'rf_max_depth': 346}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:16,806] Trial 79 finished with value: 0.7437112597299379 and parameters: {'rf_n_estimators': 571, 'rf_criterion': 'entropy', 'rf_max_depth': 924}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:19,558] Trial 80 finished with value: 0.7349736065728937 and parameters: {'rf_n_estimators': 125, 'rf_criterion': 'gini', 'rf_max_depth': 886}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:24,019] Trial 81 finished with value: 0.7299181313208796 and parameters: {'rf_n_estimators': 203, 'rf_criterion': 'entropy', 'rf_max_depth': 265}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:34,837] Trial 82 finished with value: 0.7368469957921819 and parameters: {'rf_n_estimators': 543, 'rf_criterion': 'gini', 'rf_max_depth': 579}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:32:50,109] Trial 83 finished with value: 0.7372166122322562 and parameters: {'rf_n_estimators': 732, 'rf_criterion': 'entropy', 'rf_max_depth': 328}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:33:06,591] Trial 84 finished with value: 0.7393277683213141 and parameters: {'rf_n_estimators': 862, 'rf_criterion': 'gini', 'rf_max_depth': 995}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:33:25,074] Trial 85 finished with value: 0.7404346436903931 and parameters: {'rf_n_estimators': 975, 'rf_criterion': 'gini', 'rf_max_depth': 796}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:33:26,053] Trial 86 finished with value: 0.7220352439590823 and parameters: {'rf_n_estimators': 38, 'rf_criterion': 'gini', 'rf_max_depth': 719}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:33:32,908] Trial 87 finished with value: 0.7332880765762956 and parameters: {'rf_n_estimators': 350, 'rf_criterion': 'gini', 'rf_max_depth': 746}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:33:51,304] Trial 88 finished with value: 0.7377588594738086 and parameters: {'rf_n_estimators': 968, 'rf_criterion': 'gini', 'rf_max_depth': 720}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:34:08,079] Trial 89 finished with value: 0.735871245462853 and parameters: {'rf_n_estimators': 827, 'rf_criterion': 'entropy', 'rf_max_depth': 392}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:34:20,905] Trial 90 finished with value: 0.7383026220068555 and parameters: {'rf_n_estimators': 618, 'rf_criterion': 'entropy', 'rf_max_depth': 187}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:34:23,086] Trial 91 finished with value: 0.727512026942776 and parameters: {'rf_n_estimators': 90, 'rf_criterion': 'entropy', 'rf_max_depth': 512}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:34:41,181] Trial 92 finished with value: 0.7382229191587938 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'entropy', 'rf_max_depth': 582}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:34:57,723] Trial 93 finished with value: 0.7358329456848521 and parameters: {'rf_n_estimators': 856, 'rf_criterion': 'gini', 'rf_max_depth': 265}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:08,630] Trial 94 finished with value: 0.7433825152172115 and parameters: {'rf_n_estimators': 566, 'rf_criterion': 'gini', 'rf_max_depth': 392}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:14,375] Trial 95 finished with value: 0.740038741749268 and parameters: {'rf_n_estimators': 618, 'rf_criterion': 'gini', 'rf_max_depth': 24}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:21,389] Trial 96 finished with value: 0.7406420121010644 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'gini', 'rf_max_depth': 746}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:24,547] Trial 97 finished with value: 0.7378379914024574 and parameters: {'rf_n_estimators': 155, 'rf_criterion': 'gini', 'rf_max_depth': 590}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:40,873] Trial 98 finished with value: 0.7414997215418282 and parameters: {'rf_n_estimators': 856, 'rf_criterion': 'gini', 'rf_max_depth': 632}. Best is trial 74 with value: 0.7477008418169214.
# [I 2024-06-26 05:35:47,674] Trial 99 finished with value: 0.7417247223994156 and parameters: {'rf_n_estimators': 351, 'rf_criterion': 'gini', 'rf_max_depth': 727}. Best is trial 74 with value: 0.7477008418169214.
# ['c:\\Users\\franc.FJMOYAO\\Desktop\\Programming Projects\\depression_detection\\data\\gold\\tfidf_rf.pkl']

# %%
def objective_mpnet_rf(trial):
    
    num_trees = trial.suggest_int("rf_n_estimators", 10, 1000)
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int("rf_max_depth", 2, 1000)
    classifier_obj = RandomForestClassifier(n_estimators=num_trees, criterion=criterion, max_depth=max_depth)

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(classifier_obj, X_mpnet, y_mpnet, n_jobs=-1, cv=3, scoring="f1")
    fscore = score.mean()
    return fscore

study = optuna.create_study(direction="maximize",study_name="mpnet_rf",
                             sampler=optuna.samplers.NSGAIISampler())

# Adding Attributes to Study
study.set_user_attr('contributors', ['Francisco'])
study.set_user_attr('dataset', 'mpnet')

# Store and load using joblib:
study_path = os.path.join(data_path,'mpnet_rf.pkl')
if not os.path.isfile(study_path):
    joblib.dump(study, study_path)

study = joblib.load(study_path)

study.optimize(objective_mpnet_rf, n_trials=100)
joblib.dump(study, study_path)
# Out:
# [I 2024-06-26 08:34:24,373] A new study created in memory with name: mpnet_rf
# [I 2024-06-26 08:34:59,426] Trial 0 finished with value: 0.7883702569583727 and parameters: {'rf_n_estimators': 865, 'rf_criterion': 'gini', 'rf_max_depth': 866}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:35:38,172] Trial 1 finished with value: 0.7882284030021772 and parameters: {'rf_n_estimators': 981, 'rf_criterion': 'gini', 'rf_max_depth': 99}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:35:47,971] Trial 2 finished with value: 0.7827437712251072 and parameters: {'rf_n_estimators': 228, 'rf_criterion': 'gini', 'rf_max_depth': 837}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:36:07,117] Trial 3 finished with value: 0.7873829766032507 and parameters: {'rf_n_estimators': 458, 'rf_criterion': 'gini', 'rf_max_depth': 579}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:36:43,051] Trial 4 finished with value: 0.7815142110763031 and parameters: {'rf_n_estimators': 923, 'rf_criterion': 'gini', 'rf_max_depth': 681}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:37:00,162] Trial 5 finished with value: 0.7840234946818648 and parameters: {'rf_n_estimators': 400, 'rf_criterion': 'entropy', 'rf_max_depth': 617}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:37:37,224] Trial 6 finished with value: 0.7836927179472243 and parameters: {'rf_n_estimators': 946, 'rf_criterion': 'gini', 'rf_max_depth': 860}. Best is trial 0 with value: 0.7883702569583727.
# [I 2024-06-26 08:38:10,554] Trial 7 finished with value: 0.788940846271661 and parameters: {'rf_n_estimators': 781, 'rf_criterion': 'entropy', 'rf_max_depth': 476}. Best is trial 7 with value: 0.788940846271661.
# [I 2024-06-26 08:38:44,083] Trial 8 finished with value: 0.7854047798171185 and parameters: {'rf_n_estimators': 792, 'rf_criterion': 'entropy', 'rf_max_depth': 224}. Best is trial 7 with value: 0.788940846271661.
# [I 2024-06-26 08:38:49,809] Trial 9 finished with value: 0.7800076793535231 and parameters: {'rf_n_estimators': 130, 'rf_criterion': 'entropy', 'rf_max_depth': 468}. Best is trial 7 with value: 0.788940846271661.
# [I 2024-06-26 08:39:19,903] Trial 10 finished with value: 0.7866808836437246 and parameters: {'rf_n_estimators': 698, 'rf_criterion': 'entropy', 'rf_max_depth': 366}. Best is trial 7 with value: 0.788940846271661.
# [I 2024-06-26 08:39:26,337] Trial 11 finished with value: 0.7801813500780025 and parameters: {'rf_n_estimators': 153, 'rf_criterion': 'entropy', 'rf_max_depth': 540}. Best is trial 7 with value: 0.788940846271661.
# [I 2024-06-26 08:39:56,465] Trial 12 finished with value: 0.7907501821294343 and parameters: {'rf_n_estimators': 714, 'rf_criterion': 'entropy', 'rf_max_depth': 642}. Best is trial 12 with value: 0.7907501821294343.
# [I 2024-06-26 08:40:32,659] Trial 13 finished with value: 0.7921895407175136 and parameters: {'rf_n_estimators': 632, 'rf_criterion': 'gini', 'rf_max_depth': 206}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:40:41,322] Trial 14 finished with value: 0.7749204118468347 and parameters: {'rf_n_estimators': 120, 'rf_criterion': 'entropy', 'rf_max_depth': 437}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:40:44,739] Trial 15 finished with value: 0.768340279484967 and parameters: {'rf_n_estimators': 57, 'rf_criterion': 'gini', 'rf_max_depth': 122}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:40:55,818] Trial 16 finished with value: 0.7828030030913369 and parameters: {'rf_n_estimators': 160, 'rf_criterion': 'entropy', 'rf_max_depth': 765}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:41:58,660] Trial 17 finished with value: 0.7914588499846879 and parameters: {'rf_n_estimators': 916, 'rf_criterion': 'entropy', 'rf_max_depth': 370}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:42:20,365] Trial 18 finished with value: 0.7875253495270137 and parameters: {'rf_n_estimators': 306, 'rf_criterion': 'entropy', 'rf_max_depth': 309}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:42:53,509] Trial 19 finished with value: 0.7883664214576772 and parameters: {'rf_n_estimators': 573, 'rf_criterion': 'gini', 'rf_max_depth': 500}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:43:32,795] Trial 20 finished with value: 0.787152756358851 and parameters: {'rf_n_estimators': 688, 'rf_criterion': 'gini', 'rf_max_depth': 319}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:44:01,591] Trial 21 finished with value: 0.7849235787408076 and parameters: {'rf_n_estimators': 649, 'rf_criterion': 'gini', 'rf_max_depth': 954}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:44:36,392] Trial 22 finished with value: 0.7867247790686128 and parameters: {'rf_n_estimators': 838, 'rf_criterion': 'gini', 'rf_max_depth': 380}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:45:14,567] Trial 23 finished with value: 0.7837793557938708 and parameters: {'rf_n_estimators': 1000, 'rf_criterion': 'gini', 'rf_max_depth': 560}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:45:44,675] Trial 24 finished with value: 0.7832684117875429 and parameters: {'rf_n_estimators': 790, 'rf_criterion': 'gini', 'rf_max_depth': 359}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:46:13,540] Trial 25 finished with value: 0.7848819306751644 and parameters: {'rf_n_estimators': 684, 'rf_criterion': 'entropy', 'rf_max_depth': 555}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:46:52,319] Trial 26 finished with value: 0.7890719374643546 and parameters: {'rf_n_estimators': 906, 'rf_criterion': 'entropy', 'rf_max_depth': 141}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:47:23,642] Trial 27 finished with value: 0.7878770055443622 and parameters: {'rf_n_estimators': 755, 'rf_criterion': 'entropy', 'rf_max_depth': 563}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:48:00,899] Trial 28 finished with value: 0.7842323552922891 and parameters: {'rf_n_estimators': 983, 'rf_criterion': 'gini', 'rf_max_depth': 545}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:48:17,479] Trial 29 finished with value: 0.78347366735938 and parameters: {'rf_n_estimators': 431, 'rf_criterion': 'gini', 'rf_max_depth': 587}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:49:00,043] Trial 30 finished with value: 0.7897479161615405 and parameters: {'rf_n_estimators': 993, 'rf_criterion': 'entropy', 'rf_max_depth': 709}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:49:18,855] Trial 31 finished with value: 0.7910552212603053 and parameters: {'rf_n_estimators': 455, 'rf_criterion': 'entropy', 'rf_max_depth': 703}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:49:55,003] Trial 32 finished with value: 0.7829644072991747 and parameters: {'rf_n_estimators': 957, 'rf_criterion': 'gini', 'rf_max_depth': 767}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:50:03,505] Trial 33 finished with value: 0.7854402851270993 and parameters: {'rf_n_estimators': 201, 'rf_criterion': 'entropy', 'rf_max_depth': 327}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:50:25,635] Trial 34 finished with value: 0.7861211118341327 and parameters: {'rf_n_estimators': 522, 'rf_criterion': 'entropy', 'rf_max_depth': 302}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:50:31,275] Trial 35 finished with value: 0.7821471884002932 and parameters: {'rf_n_estimators': 145, 'rf_criterion': 'gini', 'rf_max_depth': 267}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:51:07,441] Trial 36 finished with value: 0.7883353626646414 and parameters: {'rf_n_estimators': 935, 'rf_criterion': 'gini', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:51:25,635] Trial 37 finished with value: 0.7837982970153613 and parameters: {'rf_n_estimators': 460, 'rf_criterion': 'gini', 'rf_max_depth': 514}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:51:33,695] Trial 38 finished with value: 0.7874111504940308 and parameters: {'rf_n_estimators': 184, 'rf_criterion': 'entropy', 'rf_max_depth': 433}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:51:48,455] Trial 39 finished with value: 0.7871438444021125 and parameters: {'rf_n_estimators': 354, 'rf_criterion': 'entropy', 'rf_max_depth': 441}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:52:23,552] Trial 40 finished with value: 0.7885851476489041 and parameters: {'rf_n_estimators': 849, 'rf_criterion': 'entropy', 'rf_max_depth': 721}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:52:33,886] Trial 41 finished with value: 0.7847482454146709 and parameters: {'rf_n_estimators': 258, 'rf_criterion': 'gini', 'rf_max_depth': 77}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:52:38,184] Trial 42 finished with value: 0.7810980221477634 and parameters: {'rf_n_estimators': 100, 'rf_criterion': 'gini', 'rf_max_depth': 512}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:53:12,064] Trial 43 finished with value: 0.7849611374060642 and parameters: {'rf_n_estimators': 870, 'rf_criterion': 'gini', 'rf_max_depth': 123}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:53:32,803] Trial 44 finished with value: 0.7858054896533545 and parameters: {'rf_n_estimators': 538, 'rf_criterion': 'gini', 'rf_max_depth': 402}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:53:41,697] Trial 45 finished with value: 0.7820840855042258 and parameters: {'rf_n_estimators': 224, 'rf_criterion': 'gini', 'rf_max_depth': 743}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:54:19,114] Trial 46 finished with value: 0.788532331955088 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'gini', 'rf_max_depth': 517}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:54:51,981] Trial 47 finished with value: 0.7906868557401996 and parameters: {'rf_n_estimators': 791, 'rf_criterion': 'entropy', 'rf_max_depth': 545}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:55:25,014] Trial 48 finished with value: 0.7799156466430034 and parameters: {'rf_n_estimators': 864, 'rf_criterion': 'gini', 'rf_max_depth': 500}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:55:58,841] Trial 49 finished with value: 0.7871257153696304 and parameters: {'rf_n_estimators': 806, 'rf_criterion': 'entropy', 'rf_max_depth': 168}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:56:32,604] Trial 50 finished with value: 0.7872966072378785 and parameters: {'rf_n_estimators': 786, 'rf_criterion': 'entropy', 'rf_max_depth': 141}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:57:05,538] Trial 51 finished with value: 0.7838457471088188 and parameters: {'rf_n_estimators': 792, 'rf_criterion': 'entropy', 'rf_max_depth': 224}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:57:40,956] Trial 52 finished with value: 0.7848747131808791 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'gini', 'rf_max_depth': 628}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:58:00,839] Trial 53 finished with value: 0.784499258094694 and parameters: {'rf_n_estimators': 473, 'rf_criterion': 'entropy', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:58:34,860] Trial 54 finished with value: 0.788849182385206 and parameters: {'rf_n_estimators': 791, 'rf_criterion': 'entropy', 'rf_max_depth': 545}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:59:12,341] Trial 55 finished with value: 0.786538745516931 and parameters: {'rf_n_estimators': 981, 'rf_criterion': 'gini', 'rf_max_depth': 99}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:59:35,958] Trial 56 finished with value: 0.7913424969397743 and parameters: {'rf_n_estimators': 573, 'rf_criterion': 'entropy', 'rf_max_depth': 500}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:59:44,048] Trial 57 finished with value: 0.7783496420712614 and parameters: {'rf_n_estimators': 201, 'rf_criterion': 'entropy', 'rf_max_depth': 10}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:59:51,891] Trial 58 finished with value: 0.7853179381135118 and parameters: {'rf_n_estimators': 184, 'rf_criterion': 'gini', 'rf_max_depth': 624}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 08:59:59,002] Trial 59 finished with value: 0.7815924627554313 and parameters: {'rf_n_estimators': 184, 'rf_criterion': 'gini', 'rf_max_depth': 590}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:00:35,590] Trial 60 finished with value: 0.7864690724698723 and parameters: {'rf_n_estimators': 965, 'rf_criterion': 'gini', 'rf_max_depth': 721}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:00:59,249] Trial 61 finished with value: 0.7893818042700568 and parameters: {'rf_n_estimators': 602, 'rf_criterion': 'gini', 'rf_max_depth': 478}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:01:32,620] Trial 62 finished with value: 0.7883581992400527 and parameters: {'rf_n_estimators': 781, 'rf_criterion': 'entropy', 'rf_max_depth': 476}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:02:03,615] Trial 63 finished with value: 0.7847137974228064 and parameters: {'rf_n_estimators': 806, 'rf_criterion': 'gini', 'rf_max_depth': 168}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:02:41,838] Trial 64 finished with value: 0.7887719940760931 and parameters: {'rf_n_estimators': 981, 'rf_criterion': 'gini', 'rf_max_depth': 166}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:03:23,557] Trial 65 finished with value: 0.7904505655893003 and parameters: {'rf_n_estimators': 993, 'rf_criterion': 'entropy', 'rf_max_depth': 234}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:03:31,848] Trial 66 finished with value: 0.7817627526509501 and parameters: {'rf_n_estimators': 184, 'rf_criterion': 'entropy', 'rf_max_depth': 433}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:04:00,296] Trial 67 finished with value: 0.7846574450331395 and parameters: {'rf_n_estimators': 688, 'rf_criterion': 'entropy', 'rf_max_depth': 237}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:04:22,149] Trial 68 finished with value: 0.7820697026669216 and parameters: {'rf_n_estimators': 573, 'rf_criterion': 'gini', 'rf_max_depth': 63}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:05:00,544] Trial 69 finished with value: 0.7872404331973365 and parameters: {'rf_n_estimators': 916, 'rf_criterion': 'entropy', 'rf_max_depth': 954}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:05:41,088] Trial 70 finished with value: 0.7879126943390373 and parameters: {'rf_n_estimators': 983, 'rf_criterion': 'gini', 'rf_max_depth': 380}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:06:15,831] Trial 71 finished with value: 0.7882606720840842 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'gini', 'rf_max_depth': 517}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:06:44,202] Trial 72 finished with value: 0.791252580241809 and parameters: {'rf_n_estimators': 684, 'rf_criterion': 'entropy', 'rf_max_depth': 224}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:07:19,846] Trial 73 finished with value: 0.7877738021676987 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'gini', 'rf_max_depth': 838}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:07:46,026] Trial 74 finished with value: 0.7873248132323346 and parameters: {'rf_n_estimators': 632, 'rf_criterion': 'gini', 'rf_max_depth': 487}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:08:17,257] Trial 75 finished with value: 0.7845736036732599 and parameters: {'rf_n_estimators': 755, 'rf_criterion': 'entropy', 'rf_max_depth': 563}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:08:35,074] Trial 76 finished with value: 0.7844914452426178 and parameters: {'rf_n_estimators': 454, 'rf_criterion': 'gini', 'rf_max_depth': 517}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:09:05,039] Trial 77 finished with value: 0.7867109237381307 and parameters: {'rf_n_estimators': 714, 'rf_criterion': 'entropy', 'rf_max_depth': 297}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:09:20,099] Trial 78 finished with value: 0.7836277483509834 and parameters: {'rf_n_estimators': 363, 'rf_criterion': 'gini', 'rf_max_depth': 402}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:09:24,065] Trial 79 finished with value: 0.7728385885433298 and parameters: {'rf_n_estimators': 102, 'rf_criterion': 'gini', 'rf_max_depth': 703}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:09:52,931] Trial 80 finished with value: 0.7872261221892275 and parameters: {'rf_n_estimators': 703, 'rf_criterion': 'entropy', 'rf_max_depth': 476}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:10:30,817] Trial 81 finished with value: 0.7879818911798274 and parameters: {'rf_n_estimators': 906, 'rf_criterion': 'entropy', 'rf_max_depth': 206}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:11:08,119] Trial 82 finished with value: 0.7835501851508054 and parameters: {'rf_n_estimators': 870, 'rf_criterion': 'entropy', 'rf_max_depth': 517}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:11:39,999] Trial 83 finished with value: 0.7898438053115427 and parameters: {'rf_n_estimators': 838, 'rf_criterion': 'gini', 'rf_max_depth': 348}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:12:15,898] Trial 84 finished with value: 0.7863474332750116 and parameters: {'rf_n_estimators': 935, 'rf_criterion': 'gini', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:12:42,903] Trial 85 finished with value: 0.7841793131269233 and parameters: {'rf_n_estimators': 688, 'rf_criterion': 'gini', 'rf_max_depth': 319}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:12:50,343] Trial 86 finished with value: 0.7841328512906939 and parameters: {'rf_n_estimators': 170, 'rf_criterion': 'entropy', 'rf_max_depth': 545}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:13:26,030] Trial 87 finished with value: 0.7878179885181686 and parameters: {'rf_n_estimators': 865, 'rf_criterion': 'entropy', 'rf_max_depth': 437}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:13:36,958] Trial 88 finished with value: 0.7891033968616896 and parameters: {'rf_n_estimators': 261, 'rf_criterion': 'entropy', 'rf_max_depth': 555}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:13:41,219] Trial 89 finished with value: 0.7742630335056563 and parameters: {'rf_n_estimators': 107, 'rf_criterion': 'gini', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:14:13,754] Trial 90 finished with value: 0.7859691183536749 and parameters: {'rf_n_estimators': 755, 'rf_criterion': 'entropy', 'rf_max_depth': 302}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:14:48,382] Trial 91 finished with value: 0.7845540385911335 and parameters: {'rf_n_estimators': 906, 'rf_criterion': 'gini', 'rf_max_depth': 141}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:15:17,515] Trial 92 finished with value: 0.7884536545925404 and parameters: {'rf_n_estimators': 754, 'rf_criterion': 'gini', 'rf_max_depth': 646}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:15:48,370] Trial 93 finished with value: 0.7841934488268443 and parameters: {'rf_n_estimators': 791, 'rf_criterion': 'gini', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:16:30,787] Trial 94 finished with value: 0.7852583537576064 and parameters: {'rf_n_estimators': 993, 'rf_criterion': 'entropy', 'rf_max_depth': 709}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:16:48,515] Trial 95 finished with value: 0.7856265087302562 and parameters: {'rf_n_estimators': 458, 'rf_criterion': 'gini', 'rf_max_depth': 579}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:17:18,012] Trial 96 finished with value: 0.7856667372883525 and parameters: {'rf_n_estimators': 714, 'rf_criterion': 'entropy', 'rf_max_depth': 642}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:17:46,858] Trial 97 finished with value: 0.7867300065705961 and parameters: {'rf_n_estimators': 688, 'rf_criterion': 'entropy', 'rf_max_depth': 545}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:18:24,445] Trial 98 finished with value: 0.7860472032441992 and parameters: {'rf_n_estimators': 906, 'rf_criterion': 'gini', 'rf_max_depth': 203}. Best is trial 13 with value: 0.7921895407175136.
# [I 2024-06-26 09:18:32,948] Trial 99 finished with value: 0.7852686573265638 and parameters: {'rf_n_estimators': 219, 'rf_criterion': 'gini', 'rf_max_depth': 965}. Best is trial 13 with value: 0.7921895407175136.
# ['c:\\Users\\franc.FJMOYAO\\Desktop\\Programming Projects\\depression_detection\\data\\gold\\mpnet_rf.pkl']

# %%
def objective_distilroberta_rf(trial):
    
    num_trees = trial.suggest_int("rf_n_estimators", 10, 1000)
    criterion = trial.suggest_categorical('rf_criterion', ['gini', 'entropy'])
    max_depth = trial.suggest_int("rf_max_depth", 2, 1000)
    classifier_obj = RandomForestClassifier(n_estimators=num_trees, criterion=criterion, max_depth=max_depth)

    # Step 3: Scoring method:
    score = model_selection.cross_val_score(classifier_obj, X_distilroberta, y_distilroberta, n_jobs=-1, cv=3, scoring="f1")
    fscore = score.mean()
    return fscore

study = optuna.create_study(direction="maximize",study_name="distilroberta_rf",
                             sampler=optuna.samplers.NSGAIISampler())

# Adding Attributes to Study
study.set_user_attr('contributors', ['Francisco'])
study.set_user_attr('dataset', 'distilroberta')

# Store and load using joblib:
study_path = os.path.join(data_path,'distilroberta_rf.pkl')
if not os.path.isfile(study_path):
    joblib.dump(study, study_path)

study = joblib.load(study_path)

study.optimize(objective_distilroberta_rf, n_trials=100)
joblib.dump(study, study_path)
# Out:
# [I 2024-06-26 09:24:03,327] A new study created in memory with name: distilroberta_rf
# [I 2024-06-26 09:24:36,905] Trial 0 finished with value: 0.7925157629356789 and parameters: {'rf_n_estimators': 826, 'rf_criterion': 'gini', 'rf_max_depth': 72}. Best is trial 0 with value: 0.7925157629356789.
# [I 2024-06-26 09:24:45,199] Trial 1 finished with value: 0.7875852634765493 and parameters: {'rf_n_estimators': 603, 'rf_criterion': 'gini', 'rf_max_depth': 3}. Best is trial 0 with value: 0.7925157629356789.
# [I 2024-06-26 09:25:24,193] Trial 2 finished with value: 0.7979639651002582 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'entropy', 'rf_max_depth': 731}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:25:54,747] Trial 3 finished with value: 0.7946011018032619 and parameters: {'rf_n_estimators': 720, 'rf_criterion': 'entropy', 'rf_max_depth': 39}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:25:55,440] Trial 4 finished with value: 0.7340789401395461 and parameters: {'rf_n_estimators': 14, 'rf_criterion': 'gini', 'rf_max_depth': 343}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:26:02,542] Trial 5 finished with value: 0.7934725902178051 and parameters: {'rf_n_estimators': 178, 'rf_criterion': 'gini', 'rf_max_depth': 363}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:26:38,331] Trial 6 finished with value: 0.7948683004790604 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'gini', 'rf_max_depth': 507}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:27:15,366] Trial 7 finished with value: 0.794185520162691 and parameters: {'rf_n_estimators': 960, 'rf_criterion': 'gini', 'rf_max_depth': 198}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:27:50,203] Trial 8 finished with value: 0.7939687991032892 and parameters: {'rf_n_estimators': 844, 'rf_criterion': 'entropy', 'rf_max_depth': 937}. Best is trial 2 with value: 0.7979639651002582.
# [I 2024-06-26 09:28:05,981] Trial 9 finished with value: 0.8011135780262636 and parameters: {'rf_n_estimators': 382, 'rf_criterion': 'entropy', 'rf_max_depth': 72}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:28:20,591] Trial 10 finished with value: 0.7912979250319733 and parameters: {'rf_n_estimators': 343, 'rf_criterion': 'entropy', 'rf_max_depth': 515}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:28:58,853] Trial 11 finished with value: 0.7942216979714966 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'gini', 'rf_max_depth': 410}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:29:32,575] Trial 12 finished with value: 0.7988768131960162 and parameters: {'rf_n_estimators': 801, 'rf_criterion': 'entropy', 'rf_max_depth': 132}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:29:42,264] Trial 13 finished with value: 0.7948101368604195 and parameters: {'rf_n_estimators': 232, 'rf_criterion': 'entropy', 'rf_max_depth': 289}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:30:22,320] Trial 14 finished with value: 0.7961144635670557 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'entropy', 'rf_max_depth': 902}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:30:28,914] Trial 15 finished with value: 0.795179804075716 and parameters: {'rf_n_estimators': 153, 'rf_criterion': 'entropy', 'rf_max_depth': 736}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:30:36,367] Trial 16 finished with value: 0.7941307754567891 and parameters: {'rf_n_estimators': 177, 'rf_criterion': 'entropy', 'rf_max_depth': 280}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:31:13,176] Trial 17 finished with value: 0.795250145335583 and parameters: {'rf_n_estimators': 952, 'rf_criterion': 'gini', 'rf_max_depth': 870}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:31:13,777] Trial 18 finished with value: 0.7490426156158426 and parameters: {'rf_n_estimators': 11, 'rf_criterion': 'entropy', 'rf_max_depth': 497}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:31:39,840] Trial 19 finished with value: 0.7944334192346609 and parameters: {'rf_n_estimators': 670, 'rf_criterion': 'gini', 'rf_max_depth': 631}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:32:17,439] Trial 20 finished with value: 0.7965683838275498 and parameters: {'rf_n_estimators': 893, 'rf_criterion': 'entropy', 'rf_max_depth': 243}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:32:33,991] Trial 21 finished with value: 0.7981871226123954 and parameters: {'rf_n_estimators': 388, 'rf_criterion': 'entropy', 'rf_max_depth': 316}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:32:50,477] Trial 22 finished with value: 0.7947834573277963 and parameters: {'rf_n_estimators': 395, 'rf_criterion': 'entropy', 'rf_max_depth': 126}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:33:30,600] Trial 23 finished with value: 0.7938890732408613 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'entropy', 'rf_max_depth': 815}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:34:08,461] Trial 24 finished with value: 0.7955528648963522 and parameters: {'rf_n_estimators': 922, 'rf_criterion': 'entropy', 'rf_max_depth': 201}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:34:21,761] Trial 25 finished with value: 0.797625230148372 and parameters: {'rf_n_estimators': 340, 'rf_criterion': 'gini', 'rf_max_depth': 542}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:34:34,569] Trial 26 finished with value: 0.7944487051251707 and parameters: {'rf_n_estimators': 308, 'rf_criterion': 'entropy', 'rf_max_depth': 179}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:34:48,136] Trial 27 finished with value: 0.7932303391683816 and parameters: {'rf_n_estimators': 344, 'rf_criterion': 'gini', 'rf_max_depth': 735}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:35:17,781] Trial 28 finished with value: 0.7946396687065116 and parameters: {'rf_n_estimators': 770, 'rf_criterion': 'gini', 'rf_max_depth': 989}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:35:32,681] Trial 29 finished with value: 0.7954182418197696 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'entropy', 'rf_max_depth': 471}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:35:43,528] Trial 30 finished with value: 0.7986584943369929 and parameters: {'rf_n_estimators': 263, 'rf_criterion': 'entropy', 'rf_max_depth': 326}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:35:52,285] Trial 31 finished with value: 0.7955865448750687 and parameters: {'rf_n_estimators': 209, 'rf_criterion': 'entropy', 'rf_max_depth': 837}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:36:02,188] Trial 32 finished with value: 0.7963975940593754 and parameters: {'rf_n_estimators': 231, 'rf_criterion': 'entropy', 'rf_max_depth': 682}. Best is trial 9 with value: 0.8011135780262636.
# [I 2024-06-26 09:36:39,793] Trial 33 finished with value: 0.801352063106641 and parameters: {'rf_n_estimators': 909, 'rf_criterion': 'entropy', 'rf_max_depth': 576}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:36:53,676] Trial 34 finished with value: 0.7968633227668939 and parameters: {'rf_n_estimators': 352, 'rf_criterion': 'gini', 'rf_max_depth': 656}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:37:31,887] Trial 35 finished with value: 0.7927875362151059 and parameters: {'rf_n_estimators': 991, 'rf_criterion': 'gini', 'rf_max_depth': 399}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:37:46,044] Trial 36 finished with value: 0.7948689261415129 and parameters: {'rf_n_estimators': 342, 'rf_criterion': 'entropy', 'rf_max_depth': 445}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:08,570] Trial 37 finished with value: 0.7924861563823011 and parameters: {'rf_n_estimators': 572, 'rf_criterion': 'gini', 'rf_max_depth': 931}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:24,112] Trial 38 finished with value: 0.7976134788113258 and parameters: {'rf_n_estimators': 377, 'rf_criterion': 'entropy', 'rf_max_depth': 405}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:25,472] Trial 39 finished with value: 0.7742711373756772 and parameters: {'rf_n_estimators': 30, 'rf_criterion': 'gini', 'rf_max_depth': 923}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:49,767] Trial 40 finished with value: 0.7942246163539309 and parameters: {'rf_n_estimators': 585, 'rf_criterion': 'entropy', 'rf_max_depth': 999}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:55,369] Trial 41 finished with value: 0.7928687299916787 and parameters: {'rf_n_estimators': 132, 'rf_criterion': 'entropy', 'rf_max_depth': 825}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:38:59,084] Trial 42 finished with value: 0.7890617252628437 and parameters: {'rf_n_estimators': 92, 'rf_criterion': 'gini', 'rf_max_depth': 610}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:39:00,570] Trial 43 finished with value: 0.7719087008200773 and parameters: {'rf_n_estimators': 34, 'rf_criterion': 'gini', 'rf_max_depth': 707}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:39:14,466] Trial 44 finished with value: 0.7955882185108125 and parameters: {'rf_n_estimators': 336, 'rf_criterion': 'entropy', 'rf_max_depth': 328}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:39:37,304] Trial 45 finished with value: 0.7965226060485886 and parameters: {'rf_n_estimators': 591, 'rf_criterion': 'gini', 'rf_max_depth': 650}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:40:10,881] Trial 46 finished with value: 0.7944902118693976 and parameters: {'rf_n_estimators': 858, 'rf_criterion': 'gini', 'rf_max_depth': 279}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:40:48,846] Trial 47 finished with value: 0.7938471745734019 and parameters: {'rf_n_estimators': 907, 'rf_criterion': 'entropy', 'rf_max_depth': 84}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:41:13,991] Trial 48 finished with value: 0.791103340471059 and parameters: {'rf_n_estimators': 654, 'rf_criterion': 'gini', 'rf_max_depth': 285}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:41:48,594] Trial 49 finished with value: 0.7987742854236598 and parameters: {'rf_n_estimators': 834, 'rf_criterion': 'entropy', 'rf_max_depth': 715}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:42:29,800] Trial 50 finished with value: 0.798938081809197 and parameters: {'rf_n_estimators': 991, 'rf_criterion': 'entropy', 'rf_max_depth': 43}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:43:08,559] Trial 51 finished with value: 0.7948916428283496 and parameters: {'rf_n_estimators': 991, 'rf_criterion': 'gini', 'rf_max_depth': 120}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:43:46,385] Trial 52 finished with value: 0.7968025350227385 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'entropy', 'rf_max_depth': 72}. Best is trial 33 with value: 0.801352063106641.
# [I 2024-06-26 09:44:03,173] Trial 53 finished with value: 0.8047245479771928 and parameters: {'rf_n_estimators': 407, 'rf_criterion': 'entropy', 'rf_max_depth': 667}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:44:03,917] Trial 54 finished with value: 0.7266971440946284 and parameters: {'rf_n_estimators': 14, 'rf_criterion': 'entropy', 'rf_max_depth': 731}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:44:41,622] Trial 55 finished with value: 0.7970271971132998 and parameters: {'rf_n_estimators': 907, 'rf_criterion': 'entropy', 'rf_max_depth': 335}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:45:09,537] Trial 56 finished with value: 0.8003496961844511 and parameters: {'rf_n_estimators': 679, 'rf_criterion': 'entropy', 'rf_max_depth': 843}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:45:43,649] Trial 57 finished with value: 0.7963339354042055 and parameters: {'rf_n_estimators': 834, 'rf_criterion': 'entropy', 'rf_max_depth': 731}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:46:23,802] Trial 58 finished with value: 0.7972781323920999 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'entropy', 'rf_max_depth': 902}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:46:38,928] Trial 59 finished with value: 0.7967203231446313 and parameters: {'rf_n_estimators': 361, 'rf_criterion': 'entropy', 'rf_max_depth': 72}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:46:52,376] Trial 60 finished with value: 0.7918467999316449 and parameters: {'rf_n_estimators': 340, 'rf_criterion': 'gini', 'rf_max_depth': 113}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:47:28,224] Trial 61 finished with value: 0.7941416076102917 and parameters: {'rf_n_estimators': 879, 'rf_criterion': 'entropy', 'rf_max_depth': 328}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:47:28,823] Trial 62 finished with value: 0.7495815186319567 and parameters: {'rf_n_estimators': 11, 'rf_criterion': 'gini', 'rf_max_depth': 735}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:47:37,026] Trial 63 finished with value: 0.7985113501332802 and parameters: {'rf_n_estimators': 209, 'rf_criterion': 'gini', 'rf_max_depth': 201}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:48:16,964] Trial 64 finished with value: 0.7949085837750318 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'entropy', 'rf_max_depth': 566}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:48:30,379] Trial 65 finished with value: 0.7960312035290128 and parameters: {'rf_n_estimators': 340, 'rf_criterion': 'gini', 'rf_max_depth': 542}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:49:08,399] Trial 66 finished with value: 0.7926947458650321 and parameters: {'rf_n_estimators': 922, 'rf_criterion': 'entropy', 'rf_max_depth': 201}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:49:45,615] Trial 67 finished with value: 0.794239194865562 and parameters: {'rf_n_estimators': 909, 'rf_criterion': 'entropy', 'rf_max_depth': 867}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:50:18,115] Trial 68 finished with value: 0.7945638316533429 and parameters: {'rf_n_estimators': 770, 'rf_criterion': 'entropy', 'rf_max_depth': 509}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:51:18,258] Trial 69 finished with value: 0.794677686057355 and parameters: {'rf_n_estimators': 907, 'rf_criterion': 'entropy', 'rf_max_depth': 72}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:52:07,024] Trial 70 finished with value: 0.796598942585249 and parameters: {'rf_n_estimators': 834, 'rf_criterion': 'entropy', 'rf_max_depth': 132}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:52:46,126] Trial 71 finished with value: 0.7940532827007821 and parameters: {'rf_n_estimators': 909, 'rf_criterion': 'entropy', 'rf_max_depth': 280}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:52:57,582] Trial 72 finished with value: 0.7949597856888048 and parameters: {'rf_n_estimators': 263, 'rf_criterion': 'entropy', 'rf_max_depth': 326}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:53:31,576] Trial 73 finished with value: 0.7918486953452639 and parameters: {'rf_n_estimators': 801, 'rf_criterion': 'entropy', 'rf_max_depth': 132}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:54:02,064] Trial 74 finished with value: 0.8011342467832505 and parameters: {'rf_n_estimators': 729, 'rf_criterion': 'entropy', 'rf_max_depth': 207}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:54:51,568] Trial 75 finished with value: 0.7976402535935261 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'entropy', 'rf_max_depth': 507}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:55:02,028] Trial 76 finished with value: 0.7906414328780942 and parameters: {'rf_n_estimators': 175, 'rf_criterion': 'gini', 'rf_max_depth': 650}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:55:24,035] Trial 77 finished with value: 0.7939442949919839 and parameters: {'rf_n_estimators': 382, 'rf_criterion': 'entropy', 'rf_max_depth': 902}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:56:12,832] Trial 78 finished with value: 0.7926887710669567 and parameters: {'rf_n_estimators': 974, 'rf_criterion': 'gini', 'rf_max_depth': 806}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:56:21,141] Trial 79 finished with value: 0.7846189937584258 and parameters: {'rf_n_estimators': 139, 'rf_criterion': 'gini', 'rf_max_depth': 825}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:56:32,925] Trial 80 finished with value: 0.7952510486552652 and parameters: {'rf_n_estimators': 276, 'rf_criterion': 'gini', 'rf_max_depth': 715}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:56:49,328] Trial 81 finished with value: 0.7945438296870876 and parameters: {'rf_n_estimators': 406, 'rf_criterion': 'gini', 'rf_max_depth': 498}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:57:39,031] Trial 82 finished with value: 0.7953526393310622 and parameters: {'rf_n_estimators': 952, 'rf_criterion': 'gini', 'rf_max_depth': 870}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:58:32,631] Trial 83 finished with value: 0.7950820476178202 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'entropy', 'rf_max_depth': 132}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 09:59:24,997] Trial 84 finished with value: 0.796773407210498 and parameters: {'rf_n_estimators': 909, 'rf_criterion': 'entropy', 'rf_max_depth': 990}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:00:01,817] Trial 85 finished with value: 0.798977194368289 and parameters: {'rf_n_estimators': 714, 'rf_criterion': 'entropy', 'rf_max_depth': 328}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:00:20,825] Trial 86 finished with value: 0.7903395767304598 and parameters: {'rf_n_estimators': 377, 'rf_criterion': 'gini', 'rf_max_depth': 405}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:00:22,177] Trial 87 finished with value: 0.7666409306931601 and parameters: {'rf_n_estimators': 30, 'rf_criterion': 'gini', 'rf_max_depth': 402}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:01:01,638] Trial 88 finished with value: 0.7958993750105594 and parameters: {'rf_n_estimators': 913, 'rf_criterion': 'entropy', 'rf_max_depth': 731}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:01:12,753] Trial 89 finished with value: 0.7944019646936802 and parameters: {'rf_n_estimators': 263, 'rf_criterion': 'entropy', 'rf_max_depth': 326}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:01:35,273] Trial 90 finished with value: 0.7934888699242104 and parameters: {'rf_n_estimators': 539, 'rf_criterion': 'gini', 'rf_max_depth': 280}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:02:25,854] Trial 91 finished with value: 0.7926229162866778 and parameters: {'rf_n_estimators': 952, 'rf_criterion': 'gini', 'rf_max_depth': 631}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:02:49,741] Trial 92 finished with value: 0.7966442523931444 and parameters: {'rf_n_estimators': 482, 'rf_criterion': 'entropy', 'rf_max_depth': 731}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:03:07,237] Trial 93 finished with value: 0.7950914405053027 and parameters: {'rf_n_estimators': 445, 'rf_criterion': 'gini', 'rf_max_depth': 309}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:03:45,203] Trial 94 finished with value: 0.7962597347672427 and parameters: {'rf_n_estimators': 952, 'rf_criterion': 'gini', 'rf_max_depth': 870}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:04:46,301] Trial 95 finished with value: 0.7950273314662927 and parameters: {'rf_n_estimators': 889, 'rf_criterion': 'entropy', 'rf_max_depth': 326}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:04:47,211] Trial 96 finished with value: 0.7148817509914537 and parameters: {'rf_n_estimators': 14, 'rf_criterion': 'gini', 'rf_max_depth': 343}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:05:48,767] Trial 97 finished with value: 0.7946061300462982 and parameters: {'rf_n_estimators': 893, 'rf_criterion': 'entropy', 'rf_max_depth': 179}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:06:12,779] Trial 98 finished with value: 0.793168433451119 and parameters: {'rf_n_estimators': 395, 'rf_criterion': 'entropy', 'rf_max_depth': 594}. Best is trial 53 with value: 0.8047245479771928.
# [I 2024-06-26 10:06:45,566] Trial 99 finished with value: 0.7960334093343017 and parameters: {'rf_n_estimators': 826, 'rf_criterion': 'gini', 'rf_max_depth': 44}. Best is trial 53 with value: 0.8047245479771928.
# ['c:\\Users\\franc.FJMOYAO\\Desktop\\Programming Projects\\depression_detection\\data\\gold\\distilroberta_rf.pkl']

# %%
rf_studies = [os.path.join(data_path,x) for x in os.listdir(data_path) if "rf" in x]

# %%
rf_experiments = pd.DataFrame()
for study_path in rf_studies:
    cur_study = joblib.load(study_path)
    cur_study_df = cur_study.trials_dataframe()
    cur_study_df["dataset"] = cur_study.user_attrs["dataset"]
    rf_experiments = pd.concat([rf_experiments, cur_study_df])

# %%
rf_experiments.groupby("dataset")["value"].max()
# Out:
# dataset
# Manual           0.690253
# distilroberta    0.804725
# mpnet            0.792190
# tfidf            0.747701
# Name: value, dtype: float64
